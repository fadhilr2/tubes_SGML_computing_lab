# %%
import joblib
import pandas as pd

# %%
new_data = pd.DataFrame([{
    "Category": "Phones and Tablets", 
    "Location": "Jakarta Pusat", 
    "Price": 150000
}])

# %%
model = joblib.load('./e-commerce_analysis_classification_model.pkl')

# %%
predictions = model.predict(new_data)

print(f"Predictions: {predictions}")
# Out:
# Predictions: [0]
