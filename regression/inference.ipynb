# %%
import joblib
import pandas as pd

# %%
model = joblib.load('./e-commerce_analysis_regression_model.pkl')

# %%
new_data = pd.DataFrame({"Category": "Phones and Tablets", 
                         "Price": 150000, 
                         "Overall Rating": 4.7}, index=[0])

# %%
predictions = model.predict(new_data)

print(f"Predictions: {predictions}")
# Out:
# Predictions: [449.]
